# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/MIT-Emerging-Talent/ET6-CDSP-group-01-repo/refs/heads/main/1_datasets/raw_data/Rainfall_Data.csv"

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#             City        Date  Year  Month  Rainfall_mm
# 0        Kampala  2005-01-01  2005      1    41.632484
# 1    Addis Ababa  2005-01-01  2005      1    44.480564
# 2        Kampala  2005-02-01  2005      2    28.327267
# 3    Addis Ababa  2005-02-01  2005      2    19.762764
# 4        Kampala  2005-03-01  2005      3   154.920380
# ..           ...         ...   ...    ...          ...
# 485  Addis Ababa  2025-03-01  2025      3    41.306976
# 486      Kampala  2025-04-01  2025      4   156.367510
# 487  Addis Ababa  2025-04-01  2025      4    42.452282
# 488      Kampala  2025-05-01  2025      5   163.624710
# 489  Addis Ababa  2025-05-01  2025      5    57.420994
#
# [490 rows x 5 columns]

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Year"] = df["Date"].dt.year
yearly_rainfall = df.groupby(["City", "Year"])["Rainfall_mm"].sum().reset_index()
yearly_rainfall
# Out:
#            City  Year  Rainfall_mm
# 0   Addis Ababa  2005  1174.917609
# 1   Addis Ababa  2006  1322.667343
# 2   Addis Ababa  2007  1261.028727
# 3   Addis Ababa  2008  1121.388045
# 4   Addis Ababa  2009  1158.312130
# 5   Addis Ababa  2010  1322.146336
# 6   Addis Ababa  2011  1250.951537
# 7   Addis Ababa  2012  1102.145049
# 8   Addis Ababa  2013  1108.747813
# 9   Addis Ababa  2014   852.399948
# 10  Addis Ababa  2015   768.009428
# 11  Addis Ababa  2016  1164.380821
# 12  Addis Ababa  2017  1299.103063
# 13  Addis Ababa  2018  1143.844729
# 14  Addis Ababa  2019  1419.069920
# 15  Addis Ababa  2020  1249.865812
# 16  Addis Ababa  2021  1125.493761
# 17  Addis Ababa  2022  1160.791849
# 18  Addis Ababa  2023  1276.275599
# 19  Addis Ababa  2024  1259.927527
# 20  Addis Ababa  2025   161.518848
# 21      Kampala  2005  1102.198519
# 22      Kampala  2006  1305.716520
# 23      Kampala  2007  1171.827020
# 24      Kampala  2008  1134.292234
# 25      Kampala  2009  1069.026056
# 26      Kampala  2010  1253.432354
# 27      Kampala  2011  1335.471256
# 28      Kampala  2012  1365.329648
# 29      Kampala  2013  1049.832214
# 30      Kampala  2014  1191.850708
# 31      Kampala  2015  1271.579796
# 32      Kampala  2016  1051.015188
# 33      Kampala  2017  1177.956355
# 34      Kampala  2018  1392.375861
# 35      Kampala  2019  1583.994613
# 36      Kampala  2020  1602.920214
# 37      Kampala  2021  1197.421682
# 38      Kampala  2022  1437.345428
# 39      Kampala  2023  1402.097669
# 40      Kampala  2024  1177.555564
# 41      Kampala  2025   592.438357

# %%
yearly_rainfall.to_csv("yearly_rainfall.csv", index=False)
